# %% [markdown]
# ### Feature Selection by Gradient Boosting Regressor for each neighborhood

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from project import handling_missing_values, LabelEncoder
# %matplotlib inline

# %%
# Reading the data
df = pd.read_csv('train.csv', index_col=0)
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
Neighborhood = df['Neighborhood'].unique()

# %%
Neighborhood
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
for i in Neighborhood:
    vars()[i] = df.loc[df['Neighborhood'] == i]

# %%
Veenker
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 54            20       RL         68.0    50271   Pave   NaN      IR1
# 161           20       RL          NaN    11120   Pave   NaN      IR1
# 327          120       RL         32.0    10846   Pave   NaN      IR1
# 401          120       RL         38.0    14963   Pave   NaN      IR2
# 673           20       RL          NaN    11250   Pave   NaN      IR1
# 765          120       RL         30.0     9549   Pave   NaN      IR1
# 850           80       RL         80.0     9600   Pave   NaN      Reg
# 1156          20       RL         90.0    10768   Pave   NaN      IR1
# 1165          80       RL          NaN    16157   Pave   NaN      IR1
# 1254          60       RL          NaN    17542   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 54           Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 161          Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 327          Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 401          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 673          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 765          Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 850          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1156         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1165         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1254         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2          0      5    2007        WD         Normal     181500
# 54         0     11    2006        WD         Normal     385000
# 161        0      6    2008        WD         Normal     162500
# 327        0      5    2008       Con         Normal     324000
# 401        0     12    2008        WD         Normal     245500
# 673        0      6    2006        WD         Normal     165000
# 765        0      4    2006        WD         Normal     270000
# 850        0      8    2007        WD         Normal     187000
# 1156       0      7    2007        WD         Normal     218000
# 1165       0      6    2007        WD         Normal     194000
# 1254       0      7    2007        WD         Normal     294000
#
# [11 rows x 80 columns]

# %%
NPkVill
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 127          120       RL          NaN     4928   Pave   NaN      IR1
# 196          160       RL         24.0     2280   Pave   NaN      Reg
# 505          160       RL         24.0     2308   Pave   NaN      Reg
# 551          120       RL         53.0     4043   Pave   NaN      Reg
# 676          160       RL         24.0     2289   Pave   NaN      Reg
# 963          160       RL         24.0     2308   Pave   NaN      Reg
# 1161         160       RL         24.0     2280   Pave   NaN      Reg
# 1422         120       RL         53.0     4043   Pave   NaN      Reg
# 1432         120       RL          NaN     4928   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 127          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 196          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 505          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 551          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 676          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 963          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 1161         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1422         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1432         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 127        0      2    2007        WD         Normal     128000
# 196        0      7    2009        WD         Normal     148500
# 505        0      6    2009        WD         Normal     147000
# 551        0     10    2008       COD        Abnorml     140000
# 676        0      4    2009        WD         Normal     148500
# 963        0      7    2007        WD         Normal     155000
# 1161       0      7    2010        WD         Normal     146000
# 1422       0      7    2010        WD         Normal     127500
# 1432       0     10    2009        WD         Normal     143750
#
# [9 rows x 80 columns]

# %%
var_names = [CollgCr, Veenker, Crawfor, NoRidge, Mitchel, Somerst,NWAmes, OldTown, BrkSide, Sawyer, NridgHt, NAmes,
     SawyerW, IDOTRR, MeadowV, Edwards, Timber, Gilbert,StoneBr, ClearCr, NPkVill, Blmngtn, BrDale, SWISU,Blueste]
var_names[0].head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 14          20       RL         91.0    10652   Pave   NaN      IR1
# 23          20       RL         75.0     9742   Pave   NaN      Reg
# 33          20       RL         85.0    11049   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 14         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 23         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 33         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 3        0      9    2008        WD         Normal     223500
# 14       0      8    2007       New        Partial     279500
# 23       0      9    2008        WD         Normal     230000
# 33       0      1    2008        WD         Normal     179900
#
# [5 rows x 80 columns]

# %%
#don't run it does not give what I want
for indx, val in enumerate(Neighborhood):
    var_names[indx].drop(labels = 'Neighborhood', axis=1, inplace=True)
    handling_missing_values(var_names[indx])
    vars()[val] = LabelEncoder(var_names[indx])

# %%
#print(Veenker)

# %%
for neighborhood in var_names:
    neighborhood.drop(labels = 'Neighborhood', axis=1, inplace=True)
    handling_missing_values(neighborhood)
    neighborhood = LabelEncoder(neighborhood)
# Out:
# C:\Users\admin1\Anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\admin1\Anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\admin1\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\admin1\Downloads\Final Project\MachineLearning_FinalProject-master\project.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
Veenker
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 2             20         3         80.0     9600       2      0         4
# 54            20         3         68.0    50271       2      0         3
# 161           20         3         31.0    11120       2      0         3
# 327          120         3         32.0    10846       2      0         3
# 401          120         3         38.0    14963       2      0         2
# 673           20         3         53.0    11250       2      0         3
# 765          120         3         30.0     9549       2      0         3
# 850           80         3         80.0     9600       2      0         4
# 1156          20         3         90.0    10768       2      0         3
# 1165          80         3         80.0    16157       2      0         3
# 1254          60         3         53.0    17542       2      0         3
#
#      LandContour Utilities LotConfig  ...  PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 2            Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 54           Low    AllPub    Inside  ...         0      0     0      NoMisc
# 161          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 327          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 401          Lvl    AllPub    Inside  ...         0      0     0      NoMisc
# 673          Lvl    AllPub    Inside  ...         0      0     0      NoMisc
# 765          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 850          Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 1156         Lvl    AllPub    Corner  ...         0      0     0      NoMisc
# 1165         Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 1254         Lvl    AllPub    Inside  ...         0      0     3      NoMisc
#
#      MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# Id
# 2          0       5    2007        WD              6    181500
# 54         0      11    2006        WD              6    385000
# 161        0       6    2008        WD              6    162500
# 327        0       5    2008       Con              6    324000
# 401        0      12    2008        WD              6    245500
# 673        0       6    2006        WD              6    165000
# 765        0       4    2006        WD              6    270000
# 850        0       8    2007        WD              6    187000
# 1156       0       7    2007        WD              6    218000
# 1165       0       6    2007        WD              6    194000
# 1254       0       7    2007        WD              6    294000
#
# [11 rows x 79 columns]

# %%
var_names[1]
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 2             20         3         80.0     9600       2      0         4
# 54            20         3         68.0    50271       2      0         3
# 161           20         3         31.0    11120       2      0         3
# 327          120         3         32.0    10846       2      0         3
# 401          120         3         38.0    14963       2      0         2
# 673           20         3         53.0    11250       2      0         3
# 765          120         3         30.0     9549       2      0         3
# 850           80         3         80.0     9600       2      0         4
# 1156          20         3         90.0    10768       2      0         3
# 1165          80         3         80.0    16157       2      0         3
# 1254          60         3         53.0    17542       2      0         3
#
#      LandContour Utilities LotConfig  ...  PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 2            Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 54           Low    AllPub    Inside  ...         0      0     0      NoMisc
# 161          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 327          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 401          Lvl    AllPub    Inside  ...         0      0     0      NoMisc
# 673          Lvl    AllPub    Inside  ...         0      0     0      NoMisc
# 765          Lvl    AllPub   CulDSac  ...         0      0     0      NoMisc
# 850          Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 1156         Lvl    AllPub    Corner  ...         0      0     0      NoMisc
# 1165         Lvl    AllPub       FR2  ...         0      0     0      NoMisc
# 1254         Lvl    AllPub    Inside  ...         0      0     3      NoMisc
#
#      MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# Id
# 2          0       5    2007        WD              6    181500
# 54         0      11    2006        WD              6    385000
# 161        0       6    2008        WD              6    162500
# 327        0       5    2008       Con              6    324000
# 401        0      12    2008        WD              6    245500
# 673        0       6    2006        WD              6    165000
# 765        0       4    2006        WD              6    270000
# 850        0       8    2007        WD              6    187000
# 1156       0       7    2007        WD              6    218000
# 1165       0       6    2007        WD              6    194000
# 1254       0       7    2007        WD              6    294000
#
# [11 rows x 79 columns]

# %%
Dummy_names = ['CollgCr_D', 'Veenker_D', 'Crawfor_D', 'NoRidge_D', 'Mitchel_D', 'Somerst_D',
       'NWAmes_D', 'OldTown_D', 'BrkSide_D', 'Sawyer_D', 'NridgHt_D', 'NAmes_D',
       'SawyerW_D', 'IDOTRR_D', 'MeadowV_D', 'Edwards_D', 'Timber_D', 'Gilbert_D',
       'StoneBr_D', 'ClearCr_D', 'NPkVill_D', 'Blmngtn_D', 'BrDale_D', 'SWISU_D',
       'Blueste_D']

for indx, val in enumerate(Dummy_names):
    vars()[val] = pd.get_dummies(var_names[indx], drop_first= True)

# %%
Veenker_D
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 2             20         3         80.0     9600       2      0         4
# 54            20         3         68.0    50271       2      0         3
# 161           20         3         31.0    11120       2      0         3
# 327          120         3         32.0    10846       2      0         3
# 401          120         3         38.0    14963       2      0         2
# 673           20         3         53.0    11250       2      0         3
# 765          120         3         30.0     9549       2      0         3
# 850           80         3         80.0     9600       2      0         4
# 1156          20         3         90.0    10768       2      0         3
# 1165          80         3         80.0    16157       2      0         3
# 1254          60         3         53.0    17542       2      0         3
#
#       LandSlope  OverallQual  OverallCond  ...  Exterior1st_Plywood  \
# Id                                         ...
# 2             1            6            8  ...                    0
# 54            1            9            5  ...                    0
# 161           1            6            6  ...                    1
# 327           1            8            5  ...                    0
# 401           1            8            5  ...                    0
# 673           1            6            6  ...                    1
# 765           1            8            5  ...                    0
# 850           1            6            7  ...                    1
# 1156          1            5            8  ...                    1
# 1165          1            5            7  ...                    1
# 1254          1            7            7  ...                    0
#
#       Exterior1st_Wd Sdng  Exterior1st_WdShing  Exterior2nd_MetalSd  \
# Id
# 2                       0                    0                    1
# 54                      0                    1                    0
# 161                     0                    0                    0
# 327                     0                    0                    0
# 401                     0                    0                    0
# 673                     0                    0                    0
# 765                     0                    0                    0
# 850                     0                    0                    0
# 1156                    0                    0                    0
# 1165                    0                    0                    0
# 1254                    1                    0                    0
#
#       Exterior2nd_Plywood  Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  \
# Id
# 2                       0                    0                    0
# 54                      0                    0                    1
# 161                     1                    0                    0
# 327                     0                    0                    0
# 401                     0                    0                    0
# 673                     1                    0                    0
# 765                     0                    0                    0
# 850                     1                    0                    0
# 1156                    1                    0                    0
# 1165                    1                    0                    0
# 1254                    0                    1                    0
#
#       MasVnrType_None  Foundation_PConc  SaleType_WD
# Id
# 2                   1                 0            1
# 54                  1                 0            1
# 161                 1                 1            1
# 327                 1                 1            0
# 401                 1                 1            1
# 673                 1                 0            1
# 765                 1                 1            1
# 850                 0                 0            1
# 1156                1                 0            1
# 1165                1                 1            1
# 1254                1                 0            1
#
# [11 rows x 83 columns]

# %%
Dummy_var = [CollgCr_D, Veenker_D, Crawfor_D, NoRidge_D, Mitchel_D, Somerst_D,NWAmes_D, OldTown_D, BrkSide_D, Sawyer_D, NridgHt_D, NAmes_D,
     SawyerW_D, IDOTRR_D, MeadowV_D, Edwards_D, Timber_D, Gilbert_D,StoneBr_D, ClearCr_D, NPkVill_D, Blmngtn_D, BrDale_D, SWISU_D,Blueste_D]
Dummy_var[1]
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 2             20         3         80.0     9600       2      0         4
# 54            20         3         68.0    50271       2      0         3
# 161           20         3         31.0    11120       2      0         3
# 327          120         3         32.0    10846       2      0         3
# 401          120         3         38.0    14963       2      0         2
# 673           20         3         53.0    11250       2      0         3
# 765          120         3         30.0     9549       2      0         3
# 850           80         3         80.0     9600       2      0         4
# 1156          20         3         90.0    10768       2      0         3
# 1165          80         3         80.0    16157       2      0         3
# 1254          60         3         53.0    17542       2      0         3
#
#       LandSlope  OverallQual  OverallCond  ...  Exterior1st_Plywood  \
# Id                                         ...
# 2             1            6            8  ...                    0
# 54            1            9            5  ...                    0
# 161           1            6            6  ...                    1
# 327           1            8            5  ...                    0
# 401           1            8            5  ...                    0
# 673           1            6            6  ...                    1
# 765           1            8            5  ...                    0
# 850           1            6            7  ...                    1
# 1156          1            5            8  ...                    1
# 1165          1            5            7  ...                    1
# 1254          1            7            7  ...                    0
#
#       Exterior1st_Wd Sdng  Exterior1st_WdShing  Exterior2nd_MetalSd  \
# Id
# 2                       0                    0                    1
# 54                      0                    1                    0
# 161                     0                    0                    0
# 327                     0                    0                    0
# 401                     0                    0                    0
# 673                     0                    0                    0
# 765                     0                    0                    0
# 850                     0                    0                    0
# 1156                    0                    0                    0
# 1165                    0                    0                    0
# 1254                    1                    0                    0
#
#       Exterior2nd_Plywood  Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  \
# Id
# 2                       0                    0                    0
# 54                      0                    0                    1
# 161                     1                    0                    0
# 327                     0                    0                    0
# 401                     0                    0                    0
# 673                     1                    0                    0
# 765                     0                    0                    0
# 850                     1                    0                    0
# 1156                    1                    0                    0
# 1165                    1                    0                    0
# 1254                    0                    1                    0
#
#       MasVnrType_None  Foundation_PConc  SaleType_WD
# Id
# 2                   1                 0            1
# 54                  1                 0            1
# 161                 1                 1            1
# 327                 1                 1            0
# 401                 1                 1            1
# 673                 1                 0            1
# 765                 1                 1            1
# 850                 0                 0            1
# 1156                1                 0            1
# 1165                1                 1            1
# 1254                1                 0            1
#
# [11 rows x 83 columns]

# %%
top_cols = []
for df in Dummy_var:
    y = np.log(df['SalePrice'])
    x = df.drop(labels = 'SalePrice', axis=1).astype("float64")
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
    GBR = GradientBoostingRegressor(learning_rate= 0.1, n_estimators=1500, max_depth=2)
    GBR.fit(x_train, y_train)
    important_cols = x.columns[GBR.feature_importances_ > 0.0]
    values = GBR.feature_importances_[GBR.feature_importances_ > 0.0]
    top_cols.append(important_cols[np.where(values==max(values))[0][0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-3fa57d0dd64a> in <module>
#       8     important_cols = x.columns[GBR.feature_importances_ > 0.0]
#       9     values = GBR.feature_importances_[GBR.feature_importances_ > 0.0]
# ---> 10     top_cols.append(important_cols[np.where(values==max(values))[0][0]])
#
# ValueError: max() arg is an empty sequence

# %%
top_cols
# Out:
# ['GrLivArea',
#  'BedroomAbvGr',
#  'OverallQual',
#  'OverallQual',
#  'GarageArea',
#  'MSSubClass',
#  'GrLivArea',
#  'GrLivArea',
#  'HouseStyle_1Story',
#  'GarageType',
#  'GrLivArea',
#  'GrLivArea',
#  'GarageArea',
#  'CentralAir',
#  'LotArea',
#  'TotalBsmtSF',
#  'TotalBsmtSF',
#  'TotalBsmtSF',
#  'YearRemodAdd',
#  'BsmtQual',
#  'YrSold',
#  'BsmtFinSF1',
#  'HeatingQC',
#  '2ndFlrSF']

# %%
len(top_cols)
# Out:
# 24

# %%
Blueste_D
# Out:
#      MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 600         160         4         24.0     1950       2      0         4
# 957         160         4         24.0     1300       2      0         4
#
#      LandSlope  OverallQual  OverallCond  ...  PoolArea  PoolQC  Fence  \
# Id                                        ...
# 600          1            6            6  ...         0       0      4
# 957          1            6            6  ...         0       0      4
#
#      MiscVal  MoSold  YrSold  SaleCondition  SalePrice  BldgType_TwnhsE  \
# Id
# 600        0       7    2008              6     151000                0
# 957        0       5    2009              6     124000                1
#
#      SaleType_WD
# Id
# 600            0
# 957            1
#
# [2 rows x 64 columns]

# %% [markdown]
# after the error I checked the list and I found the length is 24 so the problem in last dataframe. As you see above, the last neighborhood has only 2 values so this is not enough for fitting the model. I will remove it from the list.

# %%
Dummy_var = [CollgCr_D, Veenker_D, Crawfor_D, NoRidge_D, Mitchel_D, Somerst_D,NWAmes_D, OldTown_D, BrkSide_D, Sawyer_D, NridgHt_D, NAmes_D,
     SawyerW_D, IDOTRR_D, MeadowV_D, Edwards_D, Timber_D, Gilbert_D,StoneBr_D, ClearCr_D, NPkVill_D, Blmngtn_D, BrDale_D, SWISU_D]

# %%
top_cols = []
for df in Dummy_var:
    y = np.log(df['SalePrice'])
    x = df.drop(labels = 'SalePrice', axis=1).astype("float64")
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
    GBR = GradientBoostingRegressor(learning_rate= 0.1, n_estimators=1500, max_depth=2)
    GBR.fit(x_train, y_train)
    important_cols = x.columns[GBR.feature_importances_ > 0.0]
    values = GBR.feature_importances_[GBR.feature_importances_ > 0.0]
    top_cols.append(important_cols[np.where(values==max(values))[0][0]])

# %%
top_cols
# Out:
# ['GrLivArea',
#  'Exterior1st_Plywood',
#  'OverallQual',
#  'OverallQual',
#  'GarageArea',
#  'MSSubClass',
#  'GrLivArea',
#  'GrLivArea',
#  'HouseStyle_1Story',
#  'GarageType',
#  'GrLivArea',
#  'GrLivArea',
#  'GarageArea',
#  'CentralAir',
#  'GrLivArea',
#  'TotalBsmtSF',
#  'TotalBsmtSF',
#  'TotalBsmtSF',
#  'LotArea',
#  'BsmtQual',
#  'TotalBsmtSF',
#  'TotalBsmtSF',
#  'HeatingQC',
#  '2ndFlrSF']

# %%
list(zip(Neighborhood,top_cols))
# Out:
# [('CollgCr', 'GrLivArea'),
#  ('Veenker', 'Exterior1st_Plywood'),
#  ('Crawfor', 'OverallQual'),
#  ('NoRidge', 'OverallQual'),
#  ('Mitchel', 'GarageArea'),
#  ('Somerst', 'MSSubClass'),
#  ('NWAmes', 'GrLivArea'),
#  ('OldTown', 'GrLivArea'),
#  ('BrkSide', 'HouseStyle_1Story'),
#  ('Sawyer', 'GarageType'),
#  ('NridgHt', 'GrLivArea'),
#  ('NAmes', 'GrLivArea'),
#  ('SawyerW', 'GarageArea'),
#  ('IDOTRR', 'CentralAir'),
#  ('MeadowV', 'GrLivArea'),
#  ('Edwards', 'TotalBsmtSF'),
#  ('Timber', 'TotalBsmtSF'),
#  ('Gilbert', 'TotalBsmtSF'),
#  ('StoneBr', 'LotArea'),
#  ('ClearCr', 'BsmtQual'),
#  ('NPkVill', 'TotalBsmtSF'),
#  ('Blmngtn', 'TotalBsmtSF'),
#  ('BrDale', 'HeatingQC'),
#  ('SWISU', '2ndFlrSF')]
