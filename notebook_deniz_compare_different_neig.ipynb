# %% [markdown]
# ## First, things to prepare data just like Sami did before

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import cross_val_score
from project import handling_missing_values, LabelEncoder
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/Cemil Turhan/Downloads/train.csv', index_col=0)
Neighborhood = df['Neighborhood'].unique()
for i in Neighborhood:
    vars()[i] = df.loc[df['Neighborhood'] == i]
var_names = [CollgCr, Veenker, Crawfor, NoRidge, Mitchel, Somerst,NWAmes, OldTown, BrkSide, Sawyer, NridgHt, NAmes,
     SawyerW, IDOTRR, MeadowV, Edwards, Timber, Gilbert,StoneBr, ClearCr, NPkVill, Blmngtn, BrDale, SWISU,Blueste]

# %%
for neighborhood in var_names:
    neighborhood.drop(labels = 'Neighborhood', axis=1, inplace=True)
    handling_missing_values(neighborhood)
    neighborhood = LabelEncoder(neighborhood)
# Out:
# C:\anac\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\anac\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\anac\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\Cemil Turhan\project.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
Dummy_names = ['CollgCr_D', 'Veenker_D', 'Crawfor_D', 'NoRidge_D', 'Mitchel_D', 'Somerst_D',
       'NWAmes_D', 'OldTown_D', 'BrkSide_D', 'Sawyer_D', 'NridgHt_D', 'NAmes_D',
       'SawyerW_D', 'IDOTRR_D', 'MeadowV_D', 'Edwards_D', 'Timber_D', 'Gilbert_D',
       'StoneBr_D', 'ClearCr_D', 'NPkVill_D', 'Blmngtn_D', 'BrDale_D', 'SWISU_D',
       'Blueste_D']

for indx, val in enumerate(Dummy_names):
    vars()[val] = pd.get_dummies(var_names[indx], drop_first= True)

# %%
Dummy_vars = [CollgCr_D, Veenker_D, Crawfor_D, NoRidge_D, Mitchel_D, Somerst_D,NWAmes_D, OldTown_D, BrkSide_D, Sawyer_D, NridgHt_D, NAmes_D,
     SawyerW_D, IDOTRR_D, MeadowV_D, Edwards_D, Timber_D, Gilbert_D,StoneBr_D, ClearCr_D, NPkVill_D, Blmngtn_D, BrDale_D, SWISU_D]

# %%
def top_f(model):
    CollgCr_F = [] 
    Veenker_F = []
    Crawfor_F = [] 
    NoRidge_F = []
    Mitchel_F = []
    Somerst_F = []
    NWAmes_F = []
    OldTown_F = []
    BrkSide_F = []
    Sawyer_F = []
    NridgHt_F = []
    NAmes_F = []
    SawyerW_F = []
    IDOTRR_F = []
    MeadowV_F = []
    Edwards_F = []
    Timber_F = []
    Gilbert_F = []
    StoneBr_F = []
    ClearCr_F = []
    NPkVill_F = []
    Blmngtn_F = []
    BrDale_F = []
    SWISU_F = []
    top_cols = []
    for indx,df in enumerate(Dummy_vars):
        y = np.log(df['SalePrice'])
        x = df.drop(labels = 'SalePrice', axis=1).astype("float64")
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
        model.fit(x_train, y_train)
        important_cols = x.columns[model.feature_importances_ > 0.0]
        values = model.feature_importances_[model.feature_importances_ > 0.0]
        top_cols.append(important_cols[np.where(values==max(values))[0][0]])
        if Dummy_names[indx] == 'CollgCr_D':
            for i in sorted(values,reverse=True):
                CollgCr_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'Veenker_D':
            for i in sorted(values,reverse=True):
                Veenker_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'Crawfor_D':
            for i in sorted(values,reverse=True):
                Crawfor_F.append(important_cols[np.where(values==i)[0][0]])                  
        elif Dummy_names[indx] == 'NoRidge_D':
            for i in sorted(values,reverse=True):
                NoRidge_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Mitchel_D':
            for i in sorted(values,reverse=True):
                Mitchel_F.append(important_cols[np.where(values==i)[0][0]])                    
        elif Dummy_names[indx] == 'Somerst_D':
            for i in sorted(values,reverse=True):
                Somerst_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'NWAmes_D':
            for i in sorted(values,reverse=True):
                NWAmes_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'OldTown_D':
            for i in sorted(values,reverse=True):
                OldTown_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'BrkSide_D':
            for i in sorted(values,reverse=True):
                BrkSide_F.append(important_cols[np.where(values==i)[0][0]])                     
        elif Dummy_names[indx] == 'Sawyer_D':
            for i in sorted(values,reverse=True):
                Sawyer_F.append(important_cols[np.where(values==i)[0][0]])                    
        elif Dummy_names[indx] == 'NridgHt_D':
            for i in sorted(values,reverse=True):
                NridgHt_F.append(important_cols[np.where(values==i)[0][0]])           
        elif Dummy_names[indx] == 'NAmes_D':
            for i in sorted(values,reverse=True):
                NAmes_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'SawyerW_D':
            for i in sorted(values,reverse=True):
                SawyerW_F.append(important_cols[np.where(values==i)[0][0]])                      
        elif Dummy_names[indx] == 'IDOTRR_D':
            for i in sorted(values,reverse=True):
                IDOTRR_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'MeadowV_D':
            for i in sorted(values,reverse=True):
                MeadowV_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Edwards_D':
            for i in sorted(values,reverse=True):
                Edwards_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Timber_D':
            for i in sorted(values,reverse=True):
                Timber_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Gilbert_D':
            for i in sorted(values,reverse=True):
                Gilbert_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'StoneBr_D':
            for i in sorted(values,reverse=True):
                StoneBr_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'ClearCr_D':
            for i in sorted(values,reverse=True):
                ClearCr_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'NPkVill_D':
            for i in sorted(values,reverse=True):
                NPkVill_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Blmngtn_D':
            for i in sorted(values,reverse=True):
                Blmngtn_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'BrDale_D':
            for i in sorted(values,reverse=True):
                BrDale_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'SWISU_D':
            for i in sorted(values,reverse=True):
                SWISU_F.append(important_cols[np.where(values==i)[0][0]])
                
    return Neighborhood, top_cols

# %%
def top_f_2(model):
    CollgCr_F = [] 
    Veenker_F = []
    Crawfor_F = [] 
    NoRidge_F = []
    Mitchel_F = []
    Somerst_F = []
    NWAmes_F = []
    OldTown_F = []
    BrkSide_F = []
    Sawyer_F = []
    NridgHt_F = []
    NAmes_F = []
    SawyerW_F = []
    IDOTRR_F = []
    MeadowV_F = []
    Edwards_F = []
    Timber_F = []
    Gilbert_F = []
    StoneBr_F = []
    ClearCr_F = []
    NPkVill_F = []
    Blmngtn_F = []
    BrDale_F = []
    SWISU_F = []
    top_cols = []
    for indx,df in enumerate(Dummy_vars):
        y = np.log(df['SalePrice'])
        x = df.drop(labels = 'SalePrice', axis=1).astype("float64")
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
        model.fit(x_train, y_train)
        important_cols = x.columns[abs(model.coef_) > 0.0]
        values = model.coef_[abs(model.coef_) > 0.0]
        top_cols.append(important_cols[np.where(values==max(values))[0][0]])
        if Dummy_names[indx] == 'CollgCr_D':
            for i in sorted(values,reverse=True):
                CollgCr_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'Veenker_D':
            for i in sorted(values,reverse=True):
                Veenker_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'Crawfor_D':
            for i in sorted(values,reverse=True):
                Crawfor_F.append(important_cols[np.where(values==i)[0][0]])                  
        elif Dummy_names[indx] == 'NoRidge_D':
            for i in sorted(values,reverse=True):
                NoRidge_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Mitchel_D':
            for i in sorted(values,reverse=True):
                Mitchel_F.append(important_cols[np.where(values==i)[0][0]])                    
        elif Dummy_names[indx] == 'Somerst_D':
            for i in sorted(values,reverse=True):
                Somerst_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'NWAmes_D':
            for i in sorted(values,reverse=True):
                NWAmes_F.append(important_cols[np.where(values==i)[0][0]])
        elif Dummy_names[indx] == 'OldTown_D':
            for i in sorted(values,reverse=True):
                OldTown_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'BrkSide_D':
            for i in sorted(values,reverse=True):
                BrkSide_F.append(important_cols[np.where(values==i)[0][0]])                     
        elif Dummy_names[indx] == 'Sawyer_D':
            for i in sorted(values,reverse=True):
                Sawyer_F.append(important_cols[np.where(values==i)[0][0]])                    
        elif Dummy_names[indx] == 'NridgHt_D':
            for i in sorted(values,reverse=True):
                NridgHt_F.append(important_cols[np.where(values==i)[0][0]])           
        elif Dummy_names[indx] == 'NAmes_D':
            for i in sorted(values,reverse=True):
                NAmes_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'SawyerW_D':
            for i in sorted(values,reverse=True):
                SawyerW_F.append(important_cols[np.where(values==i)[0][0]])                      
        elif Dummy_names[indx] == 'IDOTRR_D':
            for i in sorted(values,reverse=True):
                IDOTRR_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'MeadowV_D':
            for i in sorted(values,reverse=True):
                MeadowV_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Edwards_D':
            for i in sorted(values,reverse=True):
                Edwards_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Timber_D':
            for i in sorted(values,reverse=True):
                Timber_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Gilbert_D':
            for i in sorted(values,reverse=True):
                Gilbert_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'StoneBr_D':
            for i in sorted(values,reverse=True):
                StoneBr_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'ClearCr_D':
            for i in sorted(values,reverse=True):
                ClearCr_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'NPkVill_D':
            for i in sorted(values,reverse=True):
                NPkVill_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'Blmngtn_D':
            for i in sorted(values,reverse=True):
                Blmngtn_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'BrDale_D':
            for i in sorted(values,reverse=True):
                BrDale_F.append(important_cols[np.where(values==i)[0][0]])            
        elif Dummy_names[indx] == 'SWISU_D':
            for i in sorted(values,reverse=True):
                SWISU_F.append(important_cols[np.where(values==i)[0][0]])
                
    return Neighborhood, top_cols

# %%
model0=GradientBoostingRegressor(learning_rate= 0.1, n_estimators=1500, max_depth=2)
model1=RandomForestRegressor(max_depth= 50, min_samples_leaf= 2, min_samples_split= 5, n_estimators= 500)
model2 = Lasso(alpha=.001)
model3 = Ridge(alpha=20)

# %%
GBR=top_f(model0)
rf=top_f(model1)
lasso=top_f_2(model2)
ridge=top_f_2(model3)
# Out:
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11829048699580513, tolerance: 0.0006584305383935773
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0215838433414996, tolerance: 0.00039745461835659097
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008913005265733099, tolerance: 0.00023132586852290987
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012925210349695043, tolerance: 0.00015922134205273715
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17613282209457728, tolerance: 0.00033575653078050406
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07146757170379783, tolerance: 0.0009738897187881836
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.038208507415298666, tolerance: 0.000597591150038909
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027858016632247337, tolerance: 0.00050072127920319
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005207406586796123, tolerance: 0.0003962894196520496
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002524941727627282, tolerance: 5.669871292983491e-05
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027375695721025065, tolerance: 0.0006846898962819054
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01019707934713965, tolerance: 0.00016509362280054714
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012566339136927944, tolerance: 0.00015118653704077417
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009774189181597094, tolerance: 0.00025381736142793585
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0024336240111508143, tolerance: 0.00010703848551957395
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.844672845704539e-05, tolerance: 1.509719205462588e-06
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000393066959733248, tolerance: 2.1686738264951073e-05
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00028254068899775703, tolerance: 1.86880494536102e-05
#   positive)
# C:\anac\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010213323818734268, tolerance: 0.00010564325605230161
#   positive)

# %%
list(zip(rf[0], GBR[1], rf[1], lasso[1], ridge[1]))  #columns: Neighborhood, GBR, rf, lasso, ridge
# Out:
# [('CollgCr', 'GrLivArea', 'GrLivArea', 'FullBath', 'OverallCond'),
#  ('Veenker', 'TotalBsmtSF', 'BsmtUnfSF', 'MSSubClass', 'MSSubClass'),
#  ('Crawfor', 'OverallQual', 'GrLivArea', 'PavedDrive', 'GarageType'),
#  ('NoRidge', 'OverallQual', 'GrLivArea', 'BsmtFinType2', 'YrSold'),
#  ('Mitchel', 'GarageArea', 'GarageArea', 'BsmtFinType1', 'BsmtFinType1'),
#  ('Somerst', 'MSSubClass', 'LotArea', 'Fireplaces', 'YrSold'),
#  ('NWAmes', 'GrLivArea', 'GrLivArea', 'SaleType_WD', 'OverallQual'),
#  ('OldTown', 'GrLivArea', 'GrLivArea', 'CentralAir', 'OverallQual'),
#  ('BrkSide',
#   'HouseStyle_1Story',
#   'GrLivArea',
#   'Condition1_Norm',
#   'OverallQual'),
#  ('Sawyer', 'GarageType', 'GarageType', 'BsmtHalfBath', 'Exterior1st_HdBoard'),
#  ('NridgHt', 'GrLivArea', 'GrLivArea', 'LotConfig_Inside', 'OverallQual'),
#  ('NAmes', 'GrLivArea', 'GrLivArea', 'Exterior1st_BrkFace', 'SaleCondition'),
#  ('SawyerW', 'GarageArea', 'GrLivArea', 'FullBath', 'GarageType'),
#  ('IDOTRR', 'CentralAir', '1stFlrSF', 'OverallCond', 'OverallCond'),
#  ('MeadowV', 'FireplaceQu', 'GarageFinish', 'MoSold', 'OpenPorchSF'),
#  ('Edwards', 'TotalBsmtSF', 'TotalBsmtSF', 'FullBath', 'OverallCond'),
#  ('Timber', 'TotalBsmtSF', 'TotalBsmtSF', 'FireplaceQu', 'FireplaceQu'),
#  ('Gilbert', 'TotalBsmtSF', 'TotalBsmtSF', 'MasVnrType_Stone', 'YrSold'),
#  ('StoneBr', 'TotRmsAbvGrd', 'GarageArea', 'MoSold', 'EnclosedPorch'),
#  ('ClearCr', 'BsmtQual', 'BsmtQual', 'SaleCondition', 'LotFrontage'),
#  ('NPkVill', 'TotalBsmtSF', 'TotalBsmtSF', 'BsmtFinSF1', 'BsmtFinSF1'),
#  ('Blmngtn', 'GarageArea', 'YrSold', 'LotFrontage', 'BsmtFinType1'),
#  ('BrDale', 'HeatingQC', 'HeatingQC', 'SaleCondition', 'YearRemodAdd'),
#  ('SWISU', '2ndFlrSF', '2ndFlrSF', 'MoSold', 'YearBuilt')]

# %%
put_df=pd.DataFrame(GBR[1], columns=["gbr"])

# %%
put_df["rf"]=rf[1]
put_df["lasso"]=lasso[1]
put_df["ridge"]=ridge[1]

# %%
put_df
# Out:
#                   gbr            rf                lasso                ridge
# 0           GrLivArea     GrLivArea             FullBath          OverallCond
# 1         TotalBsmtSF     BsmtUnfSF           MSSubClass           MSSubClass
# 2         OverallQual     GrLivArea           PavedDrive           GarageType
# 3         OverallQual     GrLivArea         BsmtFinType2               YrSold
# 4          GarageArea    GarageArea         BsmtFinType1         BsmtFinType1
# 5          MSSubClass       LotArea           Fireplaces               YrSold
# 6           GrLivArea     GrLivArea          SaleType_WD          OverallQual
# 7           GrLivArea     GrLivArea           CentralAir          OverallQual
# 8   HouseStyle_1Story     GrLivArea      Condition1_Norm          OverallQual
# 9          GarageType    GarageType         BsmtHalfBath  Exterior1st_HdBoard
# 10          GrLivArea     GrLivArea     LotConfig_Inside          OverallQual
# 11          GrLivArea     GrLivArea  Exterior1st_BrkFace        SaleCondition
# 12         GarageArea     GrLivArea             FullBath           GarageType
# 13         CentralAir      1stFlrSF          OverallCond          OverallCond
# 14        FireplaceQu  GarageFinish               MoSold          OpenPorchSF
# 15        TotalBsmtSF   TotalBsmtSF             FullBath          OverallCond
# 16        TotalBsmtSF   TotalBsmtSF          FireplaceQu          FireplaceQu
# 17        TotalBsmtSF   TotalBsmtSF     MasVnrType_Stone               YrSold
# 18       TotRmsAbvGrd    GarageArea               MoSold        EnclosedPorch
# 19           BsmtQual      BsmtQual        SaleCondition          LotFrontage
# 20        TotalBsmtSF   TotalBsmtSF           BsmtFinSF1           BsmtFinSF1
# 21         GarageArea        YrSold          LotFrontage         BsmtFinType1
# 22          HeatingQC     HeatingQC        SaleCondition         YearRemodAdd
# 23           2ndFlrSF      2ndFlrSF               MoSold            YearBuilt

# %%
put_df.loc[put_df["gbr"]==put_df["rf"]]
# Out:
#             gbr           rf                lasso                ridge
# 0     GrLivArea    GrLivArea             FullBath          OverallCond
# 4    GarageArea   GarageArea         BsmtFinType1         BsmtFinType1
# 6     GrLivArea    GrLivArea          SaleType_WD          OverallQual
# 7     GrLivArea    GrLivArea           CentralAir          OverallQual
# 9    GarageType   GarageType         BsmtHalfBath  Exterior1st_HdBoard
# 10    GrLivArea    GrLivArea     LotConfig_Inside          OverallQual
# 11    GrLivArea    GrLivArea  Exterior1st_BrkFace        SaleCondition
# 15  TotalBsmtSF  TotalBsmtSF             FullBath          OverallCond
# 16  TotalBsmtSF  TotalBsmtSF          FireplaceQu          FireplaceQu
# 17  TotalBsmtSF  TotalBsmtSF     MasVnrType_Stone               YrSold
# 19     BsmtQual     BsmtQual        SaleCondition          LotFrontage
# 20  TotalBsmtSF  TotalBsmtSF           BsmtFinSF1           BsmtFinSF1
# 22    HeatingQC    HeatingQC        SaleCondition         YearRemodAdd
# 23     2ndFlrSF     2ndFlrSF               MoSold            YearBuilt

# %%
put_df.loc[put_df["lasso"]==put_df["ridge"]]
# Out:
#             gbr           rf         lasso         ridge
# 1   TotalBsmtSF    BsmtUnfSF    MSSubClass    MSSubClass
# 4    GarageArea   GarageArea  BsmtFinType1  BsmtFinType1
# 13   CentralAir     1stFlrSF   OverallCond   OverallCond
# 16  TotalBsmtSF  TotalBsmtSF   FireplaceQu   FireplaceQu
# 20  TotalBsmtSF  TotalBsmtSF    BsmtFinSF1    BsmtFinSF1
