# %% [markdown]
# ## SVM after removing outliers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df = pd.read_csv('selected_features.csv', index_col = 0)
df.head()
# Out:
#    MSZoning  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       3.0         65.0   8450.0          7.0          5.0     2003.0
# 1       3.0         80.0   9600.0          6.0          8.0     1976.0
# 2       3.0         68.0  11250.0          7.0          5.0     2001.0
# 3       3.0         60.0   9550.0          7.0          5.0     1915.0
# 4       3.0         84.0  14260.0          8.0          5.0     2000.0
#
#    YearRemodAdd  MasVnrArea  ExterQual  BsmtQual  ...  GrLivArea  KitchenQual  \
# 0        2003.0       196.0        4.0       4.0  ...     1710.0          4.0
# 1        1976.0         0.0        3.0       4.0  ...     1262.0          3.0
# 2        2002.0       162.0        4.0       4.0  ...     1786.0          4.0
# 3        1970.0         0.0        3.0       3.0  ...     1717.0          4.0
# 4        2000.0       350.0        4.0       4.0  ...     2198.0          4.0
#
#    TotRmsAbvGrd  Fireplaces  GarageFinish  GarageArea  WoodDeckSF  \
# 0           8.0         0.0           2.0       548.0         0.0
# 1           6.0         1.0           2.0       460.0       298.0
# 2           6.0         1.0           2.0       608.0         0.0
# 3           7.0         1.0           1.0       642.0         0.0
# 4           9.0         1.0           2.0       836.0       192.0
#
#    OpenPorchSF  Neighborhood_Crawfor  SalePrice
# 0         61.0                   0.0     208500
# 1          0.0                   0.0     181500
# 2         42.0                   0.0     223500
# 3         35.0                   1.0     140000
# 4         84.0                   0.0     250000
#
# [5 rows x 28 columns]

# %%
df = df.drop([89,524,636,706,1299],axis=0)

# %%
y = np.log(df['SalePrice'])
x = df.drop(labels = 'SalePrice', axis=1).astype("float64")
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
ss = StandardScaler()
ss.fit(x_train)
x_train = ss.transform(x_train)
x_test = ss.transform(x_test)

# %%
svr = SVR(kernel='linear', gamma ='scale', C = 0.1)
svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

# %%
svr.score(x_test,y_test)
# Out:
# 0.8951705655898501
